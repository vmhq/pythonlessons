# %%
import pandas as pd

datos = pd.read_csv("data_celsius_fahrenheit.csv")

# %%
X = datos["celsius"].values
y = datos["fahrenheit"].values

# %%
import tensorflow as tf

modelo = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)), #la entrada, los celsius: 1 solo dato
    tf.keras.layers.Dense(units=1), #la salida. También es un dato: Los grados fahrenheit
])

modelo.compile(
    optimizer=tf.keras.optimizers.Adam(.1),
    loss="mean_squared_error"
)

# %%
entrenamiento = modelo.fit(X, y, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 292ms/step - loss: 1584.2885
# Epoch 2/1000
# 1/1 [==============================] - 0s 0s/step - loss: 1469.4849
# Epoch 3/1000
# 1/1 [==============================] - 0s 0s/step - loss: 1366.5988
# Epoch 4/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1275.7690
# Epoch 5/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1197.0251
# Epoch 6/1000
# 1/1 [==============================] - 0s 0s/step - loss: 1130.2528
# Epoch 7/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1075.1656
# Epoch 8/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1031.2732
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 997.8506
# Epoch 10/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 973.9225
# Epoch 11/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 958.2648
# Epoch 12/1000
# ...

# %%
import matplotlib.pyplot as plt

plt.xlabel("Época")
plt.ylabel("Magnitud de la pérdida")
plt.plot(entrenamiento.history["loss"])

# %%
c = 1230
prediccion = modelo.predict([c])
print("{} grados celsius son {} grados fahrenheit".format(c, prediccion))
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 1230 grados celsius son [[2246.0664]] grados fahrenheit

# %%
print(modelo.layers[0].get_weights())
# Out:
# [array([[1.8000721]], dtype=float32), array([31.97768], dtype=float32)]
